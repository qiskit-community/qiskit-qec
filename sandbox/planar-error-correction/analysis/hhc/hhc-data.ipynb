# %% [markdown]
# # Data for HHC/compass code on heavy-hexagon lattice

# %%
import numpy as np
import matplotlib.pyplot as plt

# All data is for 12 rounds of syndromes
# Schedule is (Z^s X^s)^r where rs=12 and s = 1, 2, 3, or 4
# Preparation and measurement is basis is either Z or X
# Number of samples is 10,000 for p >= 0.0005
# and 100,000 for p = [0.0001, 0.0002, 0.0003, 0.0004]
# For d = 7, 9, 11, the number of samples is 100,000 for p = 0.0005 to 0.001, inclusive,
# and 1,000,000 for p = 0.0001 to 0.0004 inclusive.
# Store data in a dictionary whose key is the code distance
# and whose value is a triple of lists containing p, plogical, and sigma.
data_s1_z = {3: [
    [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [0.00034, 0.00112, 0.0026, 0.00463, 0.0072, 0.0097, 0.0112, 0.0163, 0.0205, 0.0219, 0.0231, 0.0545, 0.0891, 0.1343, 0.1937, 0.2375, 0.2693, 0.3052],
    [5.829989698772964e-05, 0.0001057712998675858, 0.00016103620501798117, 0.0002146767147617985, 0.0008455101943494679, 0.000980146452682899, 0.001052409975568299, 0.0012663298776921887, 0.0014171012023076399, 0.0014636438177789474, 0.001502286486149911, 0.0022701300291029375, 0.0028490227610655037, 0.0034099140387075944, 0.003952163073469506, 0.004255723924153429, 0.004436182928137341, 0.004605151109537468]
],
           5: [       
    [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [2e-05, 0.00011, 0.00041, 0.00086, 0.0018, 0.0027, 0.0048, 0.0071, 0.0099, 0.0121, 0.0157, 0.0382, 0.0819, 0.1436, 0.1977, 0.2533, 0.2994, 0.3445],
    [1.4142064912168937e-05, 3.316458953311482e-05, 6.40184347168832e-05, 9.269676330325277e-05, 0.0004239032547609651, 0.0005189392351643681, 0.0006911901144963212, 0.0008396603497547655, 0.0009900995049503714, 0.0010933794162388394, 0.0012431836350897865, 0.0019168837847778968, 0.002742260199014658, 0.003507012106251038, 0.003982845378084689, 0.004349230113509519, 0.004580181416295715, 0.004752287178121955]
           ],
           7: [
    [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [1e-06, 1.6e-05, 9.3e-05, 0.000262, 0.00059, 0.00128, 0.00217, 0.0036, 0.00562, 0.00629, 0.00774, 0.0367, 0.0945, 0.1635, 0.2392, 0.328, 0.3827, 0.4294],
    [1e-06, 3.999969999857499e-06, 9.643207142410869e-06, 1.6184301589244375e-05, 7.678917870233838e-05, 0.00011306521939764843, 0.00014715001709573571, 0.00018939577267612672, 0.00023639948148663202, 0.00025000996790096287, 0.00027713118196428236, 0.0018803362907886042, 0.0029253770326367005, 0.003698397330504313, 0.00426616408681166, 0.004695083000377953, 0.004860702998884455, 0.004950152967478898]
           ],
           9: [       
    [0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [7e-06, 2.3e-05, 9.6e-05, 0.00032, 0.00081, 0.0015, 0.0024, 0.00406, 0.00541, 0.00654, 0.0434, 0.117, 0.2142, 0.3099, 0.3995, 0.4409, 0.4782],
    [2.645743373790814e-06, 4.795778768823057e-06, 9.79749355656231e-06, 5.6559773603506414e-05, 8.996399243697088e-05, 0.00012238320871956973, 0.00015473409264410432, 0.0002010859725482699, 0.00023196520661204943, 0.0002548978888287176, 0.0020376602282815926, 0.003214363578271962, 0.004102867211101913, 0.004624752732177513, 0.004898201122598351, 0.004965197309113893, 0.00499549512032088]
           ],
           # Only have old data with fewer samples for p < 0.0005 for d = 11
           11: [
    [0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [1e
.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
    [1e-05, 4e-05, 8e-05, 0.00031, 0.00051, 0.00109, 0.00234, 0.0033, 0.00411, 0.0309, 0.1, 0.1959, 0.2974, 0.3909, 0.4504, 0.4912],
    [1e-05, 1.999969999474989e-05, 2.8283281270743577e-05, 5.566929127175868e-05, 7.139642830352052e-05, 0.0001043466716396782, 0.00015279226896271469, 0.00018135994297057204, 0.00020231531903166193, 0.001730554385694996, 0.0030001500112509377, 0.0039691175832216085, 0.004571368913287807, 0.004879764360091684, 0.00497558636202454, 0.004999475520046833]
           ]}

# %%
# Estimate the total logical error as the sum of the Z and X
# basis results. This estimate is px + pz + 2*py. Assuming that
# py << px, pz we should be making a small error by approximating
# the total error in this way.
def total_error(zbasislists, xbasislists):
    physical = []
    logical = []
    xlookup = {u: v for u, v in zip(xbasislists[0], xbasislists[1])}
    for i in range(len(zbasislists[0])):
        p = zbasislists[0][i]
        p1z = zbasislists[1][i]
        if p in xlookup:
            physical.append(p)
            logical.append(p1z + xlookup[p])
    return physical, logical

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s1_z[d][0], data_s1_z[d][1], yerr=data_s1_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=1, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_z[d][0], data_s1_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s1_x[d][0], data_s1_x[d][1], yerr=data_s1_x[d][2])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.ylim((-0.005,0.40))
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_x[d][0], data_s1_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s2_z[d][0], data_s2_z[d][1], yerr=data_s2_z[d][2])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, z')
plt.ylim((-0.005,0.40))
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s2_z[d][0], data_s2_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9]:
    plt.errorbar(data_s2_x[d][0], data_s2_x[d][1], yerr=data_s2_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=2, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9]:
    plt.loglog(data_s2_x[d][0], data_s2_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s3_z[d][0], data_s3_z[d][1], yerr=data_s3_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=3, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s3_z[d][0], data_s3_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=3, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9]:
    plt.errorbar(data_s3_x[d][0], data_s3_x[d][1], yerr=data_s3_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=3, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9]:
    plt.loglog(data_s3_x[d][0], data_s3_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=3, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s4_z[d][0], data_s4_z[d][1], yerr=data_s4_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=4, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s4_z[d][0], data_s4_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=4, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s4_x[d][0], data_s4_x[d][1], yerr=data_s4_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.40))
plt.title('s=4, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s4_x[d][0], data_s4_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=4, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_z[d][0][1:], data_s1_z[d][1][1:], 'rx')
    plt.loglog(data_s2_z[d][0][1:], data_s2_z[d][1][1:], 'bo')
    plt.loglog(data_s3_z[d][0][1:], data_s3_z[d][1][1:], 'gs')
    plt.loglog(data_s4_z[d][0][1:], data_s4_z[d][1][1:], 'c+')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3]:
    plt.plot(data_s1_z[d][0][1:], data_s1_z[d][1][1:], 'rx')
    plt.plot(data_s2_z[d][0][1:], data_s2_z[d][1][1:], 'bo')
    plt.plot(data_s3_z[d][0][1:], data_s3_z[d][1][1:], 'gs')
    plt.loglog(data_s4_z[d][0][1:], data_s4_z[d][1][1:], 'c+')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_x[d][0][1:], data_s1_x[d][1][1:], 'rx')
    plt.loglog(data_s2_x[d][0][1:], data_s2_x[d][1][1:], 'bo')
    plt.loglog(data_s3_x[d][0][1:], data_s3_x[d][1][1:], 'gs')
    plt.loglog(data_s4_x[d][0][1:], data_s4_x[d][1][1:], 'c+')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
print("hhc_s1 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s1_z[d], data_s1_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hhc_s1 = {
# 3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00082, 0.00296, 0.00667, 0.01184, 0.0167, 0.0217, 0.0303, 0.0382, 0.0495, 0.0558, 0.060399999999999995, 0.1323, 0.2135, 0.3079, 0.41700000000000004, 0.5121, 0.594, 0.6702]],
# 5: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [3.0000000000000004e-05, 0.00026, 0.00089, 0.0019199999999999998, 0.0036, 0.006, 0.0089, 0.0125, 0.017800000000000003, 0.0223, 0.0278, 0.0776, 0.1578, 0.2712, 0.382, 0.5044, 0.6033, 0.7019]],
# ...

# %%
print("hhc_s2 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s2_z[d], data_s2_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hhc_s2 = {
# 3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00065, 0.00265, 0.006030000000000001, 0.010669999999999999, 0.0171, 0.0233, 0.029700000000000004, 0.038, 0.049100000000000005, 0.055499999999999994, 0.060899999999999996, 0.12390000000000001, 0.20829999999999999, 0.2988, 0.38680000000000003, 0.48760000000000003, 0.5660000000000001, 0.6526000000000001]],
# 5: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [2e-05, 0.00021999999999999998, 0.0007199999999999999, 0.0016099999999999999, 0.0025, 0.005, 0.0075, 0.0115, 0.014199999999999999, 0.019200000000000002, 0.022600000000000002, 0.0702, 0.153, 0.245, 0.3607, 0.4786, 0.5689, 0.6752]],
# ...

# %%
print("hhc_s3 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s3_z[d], data_s3_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hhc_s3 = {
# 3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00067, 0.00314, 0.00682, 0.01216, 0.018, 0.0263, 0.0342, 0.0433, 0.054099999999999995, 0.0619, 0.0653, 0.1431, 0.22699999999999998, 0.32080000000000003, 0.39780000000000004, 0.49439999999999995, 0.5731999999999999, 0.6486000000000001]],
# 5: [[0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00032, 0.001, 0.00211, 0.0057, 0.0088, 0.012300000000000002, 0.0158, 0.022, 0.0262, 0.031, 0.08660000000000001, 0.1709, 0.27380000000000004, 0.3919, 0.5021, 0.6113, 0.6931]],
# ...

# %%
print("hhc_s4 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s4_z[d], data_s4_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hhc_s4 = {
# 3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.001, 0.00348, 0.00753, 0.01397, 0.0203, 0.029699999999999997, 0.035199999999999995, 0.048, 0.058800000000000005, 0.065, 0.0731, 0.1493, 0.243, 0.336, 0.43629999999999997, 0.5242, 0.5995, 0.6696]],
# 5: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [7.000000000000001e-05, 0.00026000000000000003, 0.0014000000000000002, 0.00316, 0.0066, 0.01, 0.0156, 0.0213, 0.0303, 0.0345, 0.0414, 0.1072, 0.2017, 0.3114, 0.4259, 0.5521, 0.6308, 0.7224999999999999]],
# ...

# %%
hhc_s1 = {
3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00082, 0.00296, 0.00667, 0.01184, 0.0167, 0.0217, 0.0303, 0.0382, 0.0495, 0.0558, 0.060399999999999995, 0.1323, 0.2135, 0.3079, 0.41700000000000004, 0.5121, 0.594, 0.6702]],
5: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [3.0000000000000004e-05, 0.00026, 0.00089, 0.0019199999999999998, 0.0036, 0.006, 0.0089, 0.0125, 0.017800000000000003, 0.0223, 0.0278, 0.0776, 0.1578, 0.2712, 0.382, 0.5044, 0.6033, 0.7019]],
7: [[0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [2.4e-05, 0.000129, 0.00036500000000000004, 0.00087, 0.00184, 0.0032, 0.00516, 0.00807, 0.00903, 0.010960000000000001, 0.055600000000000004, 0.1421, 0.2515, 0.3881, 0.547, 0.6693, 0.7807]],
9: [[0.0004, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.000106, 0.00087, 0.0016200000000000001, 0.0026699999999999996, 0.0046700000000000005, 0.0062, 0.00749, 0.0516, 0.1421, 0.2755, 0.43220000000000003, 0.6012, 0.7269, 0.8443]],
11: [[0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00047000000000000004, 0.00124, 0.00228, 0.00467, 0.00607, 0.00816, 0.0574, 0.1755, 0.3432, 0.4919, 0.6375, 0.7667, 0.8694000000000001]]
}
hhc_s2 = {
3: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [0.00065, 0.00265, 0.006030000000000001, 0.010669999999999999, 0.0171, 0.0233, 0.029700000000000004, 0.038, 0.049100000000000005, 0.055499999999999994, 0.060899999999999996, 0.12390000000000001, 0.20829999999999999, 0.2988, 0.38680000000000003, 0.48760000000000003, 0.5660000000000001, 0.6526000000000001]],
5: [[0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045], [2e-05, 0.00021999999999999998, 0.0007199999999999999, 0.0016099999999999999, 0.0025, 0.005, 0.0075, 0.0115, 0.014199999999999999, 0.019200000000000002, 0.022600000000000002, 0.0702, 0.153, 0.245, 0.3607, 0.4786, 0.5689, 0.6752]],
7: [[0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.00095, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045],
# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(hhc_s1[d][0], hhc_s1[d][1], 'rx-')
    plt.loglog(hhc_s2[d][0], hhc_s2[d][1], 'bo-')
    plt.loglog(hhc_s3[d][0], hhc_s3[d][1], 'gs-')
    plt.loglog(hhc_s4[d][0], hhc_s4[d][1], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5]:
    plt.plot(hhc_s1[d][0], hhc_s1[d][1], 'rx-')
    plt.plot(hhc_s2[d][0], hhc_s2[d][1], 'bo-')
    plt.plot(hhc_s3[d][0], hhc_s3[d][1], 'gs-')
    plt.plot(hhc_s4[d][0], hhc_s4[d][1], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3,5,7,9,11]:
    plt.loglog(hhc_s1[d][0], hhc_s1[d][1], 'rx-')
    plt.loglog(hhc_s2[d][0], hhc_s2[d][1], 'bo-')
    plt.loglog(hhc_s3[d][0], hhc_s3[d][1], 'gs-')
    plt.loglog(hhc_s4[d][0], hhc_s4[d][1], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3]:
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s2[d][1], hhc_s1[d][1])], 'bo-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s3[d][1], hhc_s1[d][1])], 'gs-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s4[d][1], hhc_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=3')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
hhc_s4[11][0]
# Out:
# [0.0004,
#  0.0005,
#  0.0006,
#  0.0007,
#  0.0008,
#  0.0009,
#  0.00095,
#  0.001,
#  0.0015,
#  0.002,
#  0.0025,
#  0.003,
#  0.0035,
#  0.004,
#  0.0045]

# %%
plt.figure(figsize=(12,8))
for d in [5]:
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s2[d][1], hhc_s1[d][1])], 'bo-')
    plt.plot(hhc_s3[d][0], [u/v for u, v in zip(hhc_s3[d][1], hhc_s1[d][1][1:])], 'gs-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s4[d][1], hhc_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=5')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [7]:
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s2[d][1], hhc_s1[d][1])], 'bo-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s3[d][1][1:], hhc_s1[d][1])], 'gs-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s4[d][1], hhc_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=7')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [9]:
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s2[d][1], hhc_s1[d][1])], 'bo-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s3[d][1][1:], hhc_s1[d][1])], 'gs-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s4[d][1], hhc_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=9')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [11]:
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s2[d][1][2:], hhc_s1[d][1])], 'bo-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s3[d][1][1:], hhc_s1[d][1])], 'gs-')
    plt.plot(hhc_s1[d][0], [u/v for u, v in zip(hhc_s4[d][1][2:], hhc_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=11')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(hhc_s2[3][0], hhc_s2[3][1], 'bo-')
plt.plot(hhc_s2[5][0], hhc_s2[5][1], 'rx-')
plt.plot(hhc_s2[7][0], hhc_s2[7][1], 'gs-')
plt.plot(hhc_s2[9][0], hhc_s2[9][1], 'c+-')
plt.plot(hhc_s2[11][0], hhc_s2[11][1], 'm*-')
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.loglog(hhc_s2[3][0], hhc_s2[3][1], 'bo-')
plt.loglog(data_s2_z[3][0], data_s2_z[3][1], 'bo:')
plt.loglog(hhc_s2[5][0], hhc_s2[5][1], 'rx-')
plt.loglog(data_s2_z[5][0], data_s2_z[5][1], 'rx:')
plt.loglog(hhc_s2[7][0], hhc_s2[7][1], 'gs-')
plt.loglog(data_s2_z[7][0], data_s2_z[7][1], 'gs:')
plt.loglog(hhc_s2[9][0], hhc_s2[9][1], 'c+-')
plt.loglog(data_s2_z[9][0], data_s2_z[9][1], 'c+:')
plt.loglog(hhc_s2[11][0], hhc_s2[11][1], 'm*-')
plt.loglog(data_s2_z[11][0], data_s2_z[11][1], 'm*:')
plt.grid(which='major',axis='both')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.loglog(hhc_s2[3][0], hhc_s2[3][1], 'bo-')
plt.loglog(hhc_s2[5][0], hhc_s2[5][1], 'rx-')
plt.loglog(hhc_s2[7][0], hhc_s2[7][1], 'gs-')
plt.loglog(hhc_s2[9][0], hhc_s2[9][1], 'c+-')
plt.loglog(hhc_s2[11][0], hhc_s2[11][1], 'm*-')
plt.grid(which='major',axis='both')
plt.show()

# %%
d = [3, 5, 7, 9, 11]
# error rates at p = 6e-4
s1_6em4 = [0.0217, 0.006, 0.00184, 0.00087, 0.00047000000000000004]
s2_6em4 = [0.0233, 0.005, 0.0015, 0.0005600000000000001, 0.00027]
s3_6em4 = [0.0263, 0.0088, 0.0021000000000000003, 0.00059, 0.00035]
s4_6em4 = [0.029699999999999997, 0.01, 0.0036, 0.00128, 0.0005]
plt.figure(figsize=(12,8))
plt.semilogy(d, s1_6em4, 'ro-')
plt.semilogy(d, s2_6em4, 'kx:')
plt.show()
