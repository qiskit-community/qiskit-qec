# %% [markdown]
# # Data for RSSC with Higgott-Breuckmann circuits

# %%
import numpy as np
import matplotlib.pyplot as plt

# All data is for 12 rounds of syndromes
# Schedule is (Z^s X^s)^r where rs=12 and s = 1, 2, 3, or 4
# Preparation and measurement is basis is either Z or X
# Number of samples is 10,000 for p >= 0.004
# and 100,000 for p = 0.001, 0.002, and 0.003
# Store data in a dictionary whose key is the code distance
# and whose value is a triple of lists containing p, plogical, and sigma.
data_s1_z = {3: [
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [0.00211, 0.0075, 0.01659, 0.0277, 0.0408, 0.051, 0.0558, 0.067, 0.0789, 0.0885, 0.0989, 0.1069],
    [0.00014510578746864498, 0.00027283373028722793, 0.00040391750456436636, 0.0016412008877755957, 0.0019783648280181474, 0.0022000872797241114, 0.002295465729714044, 0.0025003450106969743, 0.0026959610198558246, 0.0028403488796582394, 0.002985426314117919, 0.003090015181092471]
           ],
           5: [       
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [0.00021, 0.00181, 0.00631, 0.0127, 0.0269, 0.0356, 0.0477, 0.0617, 0.0706, 0.0842, 0.1038, 0.1195],
    [4.582117409888094e-05, 0.00013441510210611285, 0.0002504046046394919, 0.0011198198067724843, 0.001617992827573413, 0.0018529995576729297, 0.002131413918629897, 0.0024062190234886973, 0.0025616830838380853, 0.0027770140764349885, 0.0030501616922115563, 0.0032439215931847477]
           ],
           7: [
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [2e-05, 0.00036, 0.00227, 0.0064, 0.0181, 0.0266, 0.0395, 0.049, 0.066, 0.0811, 0.0987, 0.1263],
    [1.4142064912168937e-05, 5.998949897606976e-05, 0.00015049484206103167, 0.000797475765625311, 0.0013331979379200103, 0.001609193260703956, 0.001947910273971454, 0.0021587880944186396, 0.002482945126588617, 0.0027300227659179405, 0.0029827371107872054, 0.0033220377170434636]
           ],
           9: [       
    [0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [0.00011, 0.00082, 0.0035, 0.0119, 0.0213, 0.0318, 0.0446, 0.0649, 0.0817, 0.1002, 0.134],
    [3.316458953311482e-05, 9.05171692751123e-05, 0.0005906012876620731, 0.0010844153243382195, 0.0014438973245866186, 0.0017547603592490456, 0.0020643425469178077, 0.002463616435363683, 0.00273920815677316, 0.003002814960960628, 0.003406693493118453]
           ],
           11: [
    [0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [2e-05, 0.00024, 0.0018, 0.0088, 0.0142, 0.0238, 0.0352, 0.0574, 0.0814, 0.1033, 0.1351],
    [1.4142064912168937e-05, 4.8984160648927575e-05, 0.0004239032547609651, 0.0009339931661010334, 0.0011832058137111058, 0.0015243321025406123, 0.0018429421161730382, 0.0023261696211821377, 0.0027346209637135305, 0.0030436552669016862, 0.0034184744546010104]
           ]}
data_s1_x = {3: [
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [0.00217, 0.00887, 0.01921, 0.0332, 0.0488, 0.0584, 0.0707, 0.086, 0.1009, 0.1092, 0.1144, 0.127],
    [0.00014715001709573571, 0.000296503136814944, 0.0004340641002391596, 0.0017916743592798804, 0.0021546044258803523, 0.0023450999870783633, 0.002563358749923249, 0.0028037806830442107, 0.0030121132585990626, 0.003119055762708498, 0.0031831238159585893, 0.003329896217734434]
],
           5: [       
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [0.00023, 0.0024, 0.00809, 0.0182, 0.0341, 0.0437, 0.058, 0.0655, 0.0826, 0.0964, 0.1116, 0.1287],
    [4.795303947551135e-05, 0.00015473409264410432, 0.0002832778167510026, 0.0013368076546274512, 0.001814951350543723, 0.002044370060653034, 0.0023375513715513216, 0.002474184140017851, 0.0027529042569956587, 0.002951537761492431, 0.00314889433826468, 0.003348843453380215]
           ],
           7: [
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [3e-05, 0.0007, 0.00324, 0.0097, 0.0231, 0.0326, 0.0432, 0.0567, 0.0762, 0.0953, 0.1125, 0.1277],
    [1.7320334868009898e-05, 8.363713261285036e-05, 0.00017970906196814208, 0.000980146452682899, 0.001502286486149911, 0.00177596154348578, 0.0020331722452704036, 0.0023128004463399904, 0.0026533111400664266, 0.0029364354692937716, 0.003159964167099642, 0.003337721533996485]
           ],
           9: [       
    [0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [3e-05, 0.00022, 0.00144, 0.0069, 0.0167, 0.0235, 0.0387, 0.0492, 0.0641, 0.0856, 0.1065, 0.1292],
    [1.7320334868009898e-05, 4.689923235384513e-05, 0.00011991416844592612, 0.0008278330331371631, 0.00128151286670199, 0.001514927226123435, 0.0019288864819646673, 0.0021629618212959836, 0.002449432377490179, 0.002797864686628084, 0.003084919232762386, 0.0033543794040207515]
           ],
           11: [
    [0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085],
    [2e-05, 0.00048, 0.0025, 0.0106, 0.0194, 0.0265, 0.0459, 0.0628, 0.0839, 0.1075, 0.1403],
    [1.4142064912168937e-05, 6.926574894881145e-05, 0.0004993995794892096, 0.001024143001191088, 0.0013793310898495483, 0.0016062481138666997, 0.0020927868920885303, 0.002426150164450265, 0.002772516489539508, 0.0030976336990440534, 0.0034731537944248845]
           ]}

# %%
# Estimate the total logical error as the sum of the Z and X
# basis results. This estimate is px + pz + 2*py. Assuming that
# py << px, pz we should be making a small error by approximating
# the total error in this way.
def total_error(zbasislists, xbasislists):
    physical = []
    logical = []
    xlookup = {u: v for u, v in zip(xbasislists[0], xbasislists[1])}
    for i in range(len(zbasislists[0])):
        p = zbasislists[0][i]
        p1z = zbasislists[1][i]
        if p in xlookup:
            physical.append(p)
            logical.append(p1z + xlookup[p])
    return physical, logical

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s1_z[d][0], data_s1_z[d][1], yerr=data_s1_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=1, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_z[d][0], data_s1_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s1_x[d][0], data_s1_x[d][1], yerr=data_s1_x[d][2])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.ylim((-0.005,0.22))
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_x[d][0], data_s1_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=1, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s2_z[d][0], data_s2_z[d][1], yerr=data_s2_z[d][2])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, z')
plt.ylim((-0.005,0.22))
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s2_z[d][0], data_s2_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s2_x[d][0], data_s2_x[d][1], yerr=data_s2_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=2, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s2_x[d][0], data_s2_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=2, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s3_z[d][0], data_s3_z[d][1], yerr=data_s3_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=3, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s3_z[d][0], data_s3_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=3, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s3_x[d][0], data_s3_x[d][1], yerr=data_s3_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=3, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.ylim((-0.005,0.22))
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s3_x[d][0], data_s3_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=3, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s4_z[d][0], data_s4_z[d][1], yerr=data_s4_z[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=4, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s4_z[d][0], data_s4_z[d][1])
plt.grid(which='major',axis='both')
plt.title('s=4, rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.errorbar(data_s4_x[d][0], data_s4_x[d][1], yerr=data_s4_x[d][2])
plt.grid(which='major',axis='both')
plt.ylim((-0.005,0.22))
plt.title('s=4, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s4_x[d][0], data_s4_x[d][1])
plt.grid(which='major',axis='both')
plt.title('s=4, rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_z[d][0][1:], data_s1_z[d][1][1:], 'rx')
    plt.loglog(data_s2_z[d][0][1:], data_s2_z[d][1][1:], 'bo')
    plt.loglog(data_s3_z[d][0][1:], data_s3_z[d][1][1:], 'gs')
#    plt.loglog(data_s4_z[d][0][1:], data_s4_z[d][1][1:], 'c+')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, z')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
xdata = np.linspace(1e-3, 5e-3)
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(data_s1_x[d][0][1:], data_s1_x[d][1][1:], 'rx')
    plt.loglog(data_s2_x[d][0][1:], data_s2_x[d][1][1:], 'bo')
    plt.loglog(data_s3_x[d][0][1:], data_s3_x[d][1][1:], 'gs')
#    plt.loglog(data_s4_x[d][0][1:], data_s4_x[d][1][1:], 'c+')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, x')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
print("hb_s1 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s1_z[d], data_s1_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hb_s1 = {
# 3: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00428, 0.01637, 0.0358, 0.060899999999999996, 0.08960000000000001, 0.1094, 0.1265, 0.153, 0.17980000000000002, 0.1977, 0.2133, 0.2339]],
# 5: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.0005, 0.00396, 0.01455, 0.0341, 0.06459999999999999, 0.08549999999999999, 0.11180000000000001, 0.1373, 0.1648, 0.19390000000000002, 0.2337, 0.26849999999999996]],
# 7: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00089, 0.0054800000000000005, 0.0174, 0.046200000000000005, 0.0639, 0.09179999999999999, 0.1217, 0.16210000000000002, 0.199, 0.24330000000000002, 0.2989]],
# 9: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.0002, 0.00219, 0.0099, 0.030600000000000002, 0.0547, 0.0799, 0.115, 0.162, 0.1996, 0.24719999999999998, 0.317]],
# ...

# %%
print("hb_s2 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s2_z[d], data_s2_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hb_s2 = {
# 3: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00367, 0.01416, 0.03095, 0.058800000000000005, 0.0891, 0.1031, 0.1179, 0.1454, 0.16599999999999998, 0.1797, 0.1974, 0.2203]],
# 5: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00039000000000000005, 0.0035900000000000003, 0.01134, 0.0253, 0.0501, 0.07139999999999999, 0.0928, 0.11480000000000001, 0.1339, 0.1641, 0.193, 0.2303]],
# 7: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [3.0000000000000004e-05, 0.00059, 0.0033, 0.0117, 0.0314, 0.0469, 0.0639, 0.092, 0.1203, 0.1508, 0.1915, 0.235]],
# 9: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00011, 0.00122, 0.0063, 0.0207, 0.0366, 0.0531, 0.07869999999999999, 0.10930000000000001, 0.14329999999999998, 0.1955, 0.24969999999999998]],
# ...

# %%
print("hb_s3 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s3_z[d], data_s3_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hb_s3 = {
# 3: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.0037800000000000004, 0.014499999999999999, 0.03208, 0.0516, 0.0886, 0.1066, 0.1201, 0.1376, 0.1567, 0.1787, 0.19690000000000002, 0.21739999999999998]],
# 5: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00041, 0.0038200000000000005, 0.012490000000000001, 0.0271, 0.0586, 0.0701, 0.0844, 0.1064, 0.133, 0.1605, 0.1916, 0.22]],
# 7: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [2e-05, 0.0007999999999999999, 0.004399999999999999, 0.0143, 0.0305, 0.0489, 0.0619, 0.0855, 0.10919999999999999, 0.1436, 0.1751, 0.2086]],
# 9: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00014000000000000001, 0.0015, 0.007299999999999999, 0.018, 0.0305, 0.0499, 0.07039999999999999, 0.09720000000000001, 0.1308, 0.17370000000000002, 0.2122]],
# ...

# %%
print("hb_s4 = {")
for d in [3, 5, 7, 9, 11]:
    phys, logi = total_error(data_s4_z[d], data_s4_x[d])
    if d != 11:
        print("%d: %s," % (d, [phys, logi]))
    else:
        print("%d: %s" % (d, [phys, logi]))
print("}")
# Out:
# hb_s4 = {
# 3: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.0037800000000000004, 0.015189999999999999, 0.03426, 0.061, 0.0906, 0.1109, 0.11960000000000001, 0.1369, 0.157, 0.17930000000000001, 0.1975, 0.2167]],
# 5: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00047000000000000004, 0.00415, 0.014249999999999999, 0.0319, 0.06129999999999999, 0.0777, 0.10200000000000001, 0.1197, 0.1459, 0.1745, 0.2033, 0.2309]],
# 7: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [6e-05, 0.00114, 0.0054, 0.0172, 0.0384, 0.0559, 0.0752, 0.1017, 0.1313, 0.16349999999999998, 0.1935, 0.2258]],
# 9: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00031, 0.0024400000000000003, 0.010499999999999999, 0.027200000000000002, 0.0381, 0.0612, 0.0832, 0.1097, 0.14839999999999998, 0.18280000000000002, 0.22460000000000002]],
# ...

# %%
hb_s1 = {
3: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00428, 0.01637, 0.0358, 0.060899999999999996, 0.08960000000000001, 0.1094, 0.1265, 0.153, 0.17980000000000002, 0.1977, 0.2133, 0.2339]],
5: [[0.001, 0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0
.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [0.00031, 0.0024400000000000003, 0.010499999999999999, 0.027200000000000002, 0.0381, 0.0612, 0.0832, 0.1097, 0.14839999999999998, 0.18280000000000002, 0.22460000000000002]],
11: [[0.002, 0.003, 0.004, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085], [5e-05, 0.0008, 0.004, 0.017, 0.0292, 0.043, 0.07440000000000001, 0.1008, 0.1362, 0.1817, 0.2336]]
}

# %%
plt.figure(figsize=(12,8))
for d in [3, 5, 7, 9, 11]:
    plt.loglog(hb_s1[d][0], hb_s1[d][1], 'rx-')
    plt.loglog(hb_s2[d][0], hb_s2[d][1], 'bo-')
    plt.loglog(hb_s3[d][0], hb_s3[d][1], 'gs-')
    plt.loglog(hb_s4[d][0], hb_s4[d][1], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3, 5]:
    plt.plot(hb_s1[d][0], hb_s1[d][1], 'rx-')
    plt.plot(hb_s2[d][0], hb_s2[d][1], 'bo-')
    plt.plot(hb_s3[d][0], hb_s3[d][1], 'gs-')
    plt.plot(hb_s4[d][0], hb_s4[d][1], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[1, 2, 3, 4], rs=12, total')
plt.xlabel('p')
plt.ylabel('p(fail)')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [3]:
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s2[d][1], hb_s1[d][1])], 'bo-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s3[d][1], hb_s1[d][1])], 'gs-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s4[d][1], hb_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=3')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [5]:
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s2[d][1], hb_s1[d][1])], 'bo-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s3[d][1], hb_s1[d][1])], 'gs-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s4[d][1], hb_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=5')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [7]:
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s2[d][1][1:], hb_s1[d][1])], 'bo-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s3[d][1][1:], hb_s1[d][1])], 'gs-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s4[d][1][1:], hb_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=7')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [9]:
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s2[d][1], hb_s1[d][1])], 'bo-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s3[d][1], hb_s1[d][1])], 'gs-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s4[d][1], hb_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=9')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
for d in [11]:
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s2[d][1], hb_s1[d][1])], 'bo-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s3[d][1], hb_s1[d][1])], 'gs-')
    plt.plot(hb_s1[d][0], [u/v for u, v in zip(hb_s4[d][1], hb_s1[d][1])], 'c+-')
plt.grid(which='major',axis='both')
plt.title('s=[2, 3, 4], rs=12, d=11')
plt.xlabel('p')
plt.ylabel('p(fail) ratio')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(hb_s1[3][0], hb_s1[3][1], 'bo-')
plt.plot(hb_s1[5][0], hb_s1[5][1], 'rx-')
plt.plot(hb_s1[7][0], hb_s1[7][1], 'gs-')
plt.plot(hb_s1[9][0], hb_s1[9][1], 'c+-')
plt.plot(hb_s1[11][0], hb_s1[11][1], 'm*-')
plt.grid(which='major',axis='both')
plt.ylim([0, 0.35])
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(hb_s2[3][0], hb_s2[3][1], 'bo-')
plt.plot(hb_s2[5][0], hb_s2[5][1], 'rx-')
plt.plot(hb_s2[7][0], hb_s2[7][1], 'gs-')
plt.plot(hb_s2[9][0], hb_s2[9][1], 'c+-')
plt.plot(hb_s2[11][0], hb_s2[11][1], 'm*-')
plt.grid(which='major',axis='both')
plt.ylim([0, 0.35])
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.loglog(hb_s2[3][0], hb_s2[3][1], 'bo-')
plt.loglog(data_s2_z[3][0], data_s2_z[3][1], 'bo:')
plt.loglog(hb_s2[5][0], hb_s2[5][1], 'rx-')
plt.loglog(data_s2_z[5][0], data_s2_z[5][1], 'rx:')
plt.loglog(hb_s2[7][0], hb_s2[7][1], 'gs-')
plt.loglog(data_s2_z[7][0], data_s2_z[7][1], 'gs:')
plt.loglog(hb_s2[9][0], hb_s2[9][1], 'c+-')
plt.loglog(data_s2_z[9][0], data_s2_z[9][1], 'c+:')
plt.loglog(hb_s2[11][0], hb_s2[11][1], 'm*-')
plt.loglog(data_s2_z[11][0], data_s2_z[11][1], 'm*:')
plt.grid(which='major',axis='both')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.loglog(hb_s2[3][0], hb_s2[3][1], 'bo-')
plt.loglog(hb_s2[5][0], hb_s2[5][1], 'rx-')
plt.loglog(hb_s2[7][0], hb_s2[7][1], 'gs-')
plt.loglog(hb_s2[9][0], hb_s2[9][1], 'c+-')
plt.loglog(hb_s2[11][0], hb_s2[11][1], 'm*-')
plt.grid(which='major',axis='both')
plt.show()

# %%
d = [3, 5, 7, 9, 11]
# error rates at p = 2e-3
s1_2em3 = [0.01637, 0.00396, 0.00089, 0.0002, 4e-05]
s2_2em3 = [0.01416, 0.00359, 0.00059, 0.00011, 2e-05]
s3_2em3 = [0.014499999, 0.0038200000000000005, 0.0007999999999999999, 0.00014000000000000001, 4e-05]
s4_2em3 = [0.015189999999999999, 0.00415, 0.00114, 0.00031, 5e-05]
plt.figure(figsize=(12,8))
plt.semilogy(d, s1_2em3, 'ro-')
plt.semilogy(d, s2_2em3, 'kx:')
plt.show()
